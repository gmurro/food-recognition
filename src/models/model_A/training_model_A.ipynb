# %% [markdown]
# # **Project #4 - Food Recognition**
# ### Deep Learning course - A.Y. 2020-2021
# Students:
#
# - Giuseppe	Murro	(0000997317 $-$ giuseppe.murro@studio.unibo.it)
# - Salvatore	Pisciotta	(0000985203 $-$ salvatore.pisciotta2@studio.unibo.it)

# %% [markdown]
# ## ***TRAINING MODEL A***

# %% [markdown]
# ### Preliminary settings

# %% [markdown]
# Check if the runtime is on Colab

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# %% [markdown]
# Install extern libraries if they are not installed

# %%
# !pip install segmentation_models
# !pip install visualkeras

# %% [markdown]
# Clone the repo in order to access to the dataset if the runtime is on Colab

# %%
if IN_COLAB:
    # !git clone https://github.com/gmurro/FoodRecognition.git
    # %cd /content/FoodRecognition/src
    SRC_PATH = ""
else:
    # Add path of the SRC folder in order to import custom libraries
    import sys
    SRC_PATH = "../../"
    sys.path.insert(1, SRC_PATH)

# %% [markdown]
# Import useful libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import os
from PIL import Image

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

from utils import segmentation_utils

# %env SM_FRAMEWORK = tf.keras
import segmentation_models as sm
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# ### Data acquisition

# %% [markdown]
# Define the categories of food on which we want train the segmentation model

# %%
cat_names = ['water'
             , 'bread-white'
             , 'salad-leaf-salad-green'
             , 'tomato'
             , 'butter'
             , 'carrot'
             , 'coffee-with-caffeine'
             , 'rice'
             , 'egg'
             , 'mixed-vegetables'
             , 'wine-red'
             , 'apple'
             , 'jam'
             , 'potatoes-steamed'
             , 'banana'
             , 'cheese' ]
             
batch_size = 64
img_size = (128,128)
num_classes = len(cat_names) + 1
num_filters = 32

# %% [markdown]
# Define the class `DataGenerator`, which will be used for real-time data feeding to our Keras model.
# We make the latter inherit the properties of `keras.utils.Sequence` so that we can leverage nice functionalities such as *multiprocessing*.

# %%
class DataGenerator(tf.keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, coco, batch_size, img_size, img_ids, img_paths, cat_to_class, aug_args=None, shuffle=True):
        self.coco = coco
        self.batch_size = batch_size
        self.img_size = img_size
        self.img_paths = img_paths
        self.img_ids = img_ids
        self.cat_to_class = cat_to_class
        self.aug_args = aug_args
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        """ Number of batches per epoch """
        return len(self.img_ids) // self.batch_size

    def __getitem__(self, idx):
        """ Generate one batch of data """

        # Generate indexes of the batch
        indexes = self.indexes[idx * self.batch_size:(idx + 1) * self.batch_size]

        # n of categories
        n_cat = len(self.cat_to_class)

        # Find list of img paths and image ids to read in the batch
        batch_img_paths = [self.img_paths[i] for i in indexes]
        batch_img_ids = [self.img_ids[i] for i in indexes]

        # load imgs
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype=np.float32)
        for j, path in enumerate(batch_img_paths):
            img = img_to_array(load_img(path, target_size=self.img_size))
            x[j] = img

        # load masks
        y = np.zeros((self.batch_size,) + self.img_size + (n_cat,), dtype=np.float32)
        for j, img_id in enumerate(batch_img_ids):
            mask = segmentation_utils.load_mask(self.coco, img_id, self.cat_to_class)

            # scale down mask
            mask_scaled = np.zeros(self.img_size+ (n_cat,), dtype=np.uint8)
            for i in range(n_cat):
                mask_scaled[:,:,i] = Image.fromarray(mask[:,:,i]).resize(self.img_size, Image.NEAREST)

            y[j] = np.array(mask_scaled, dtype=np.float32)
            
        if self.aug_args is not None:
            x, y = segmentation_utils.augment(x, y, self.aug_args)
            
            #
            
        return x, y

    def on_epoch_end(self):
        """ Method called at the end of every epoch that updates indexes """
        self.indexes = np.arange(len(self.img_ids))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

# %% [markdown]
# Show some examples of images from the validation set

# %%
# @title Show some images
path_dir = SRC_PATH+"../data/val/"   # @param {type: "string"}

# load images and other info from annotations (filtering only images containing foods in cat_names)
coco = segmentation_utils.load_coco_dataset(path_dir)
img_ids, img_names, cat_names, cat_to_class = segmentation_utils.load_imgs(coco, cat_names)

# load all data
x, y = segmentation_utils.load_data(coco, path_dir+"images/", img_size, cat_names)
# Out:
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# Loading images:
# 546/554 [============================>.] - ETA: 0s
# Loading masks:
# 552/554 [============================>.] - ETA: 0s

# %%
# show 3 random image and compare with augmentation
n = 3

# parameters for the augmetation
aug_args = dict(
                  rotation_range=5              # @param {type:"slider", min:0, max:10, step:1}
                , width_shift_range=0.01        # @param {type:"slider", min:0, max:0.1, step:0.01}
                , height_shift_range=0.01       # @param {type:"slider", min:0, max:0.1, step:0.01}
                , brightness_range=(0.8, 1.2)  
                , shear_range=0.01              # @param {type:"slider", min:0, max:0.1, step:0.01}
                , zoom_range=[0.7, 1]           
                , horizontal_flip=True          # @param {type:"boolean"} 
                , vertical_flip=True            # @param {type:"boolean"} 
                , fill_mode='constant'          #@param ["constant", "nearest", "reflect", "wrap"] {type:"raw"}
                , data_format='channels_last')

idx = random.randint(0, len(x)-1-n)

for i in range(idx,idx+n):
    print("\nImage {}".format(i))

    # show image not augmented
    segmentation_utils.show_mask(x[i,:,:]/255, y[i,:,:,:], cat_names)

    # show the same image augmented
    x_p = x[i].reshape((1,)+x[i].shape)
    y_p = y[i].reshape((1,)+y[i].shape)
    x_aug, y_aug = segmentation_utils.augment(x_p, y_p, aug_args)
    segmentation_utils.show_mask(x_aug[0,:,:]/255, y_aug[0,:,:,:], cat_names)
# Out:
# Image 8
# Image 9
# Image 10

# %% [markdown]
# Instantiate Data Generators for training set

# %%
# @title DataGenerator from training set
path_dir = SRC_PATH+"../data/train/"   # @param {type: "string"}

# load images and other info from annotations (filtering only images containing foods in cat_names)
coco = segmentation_utils.load_coco_dataset(path_dir)
img_ids, img_names, cat_names, cat_to_class = segmentation_utils.load_imgs(coco, cat_names)

# compute the class weights
class_dist = segmentation_utils.get_class_dist(coco, cat_names)
class_weights = segmentation_utils.get_class_weights(class_dist)

img_paths = [os.path.join(path_dir+"images/", file_name) for file_name in img_names]

# parameters for the augmetation
aug_args = dict(
                  rotation_range=5              # @param {type:"slider", min:0, max:10, step:1}
                , width_shift_range=0.01        # @param {type:"slider", min:0, max:0.1, step:0.01}
                , height_shift_range=0.01       # @param {type:"slider", min:0, max:0.1, step:0.01}
                , brightness_range=(0.8, 1.2)  
                , shear_range=0.01              # @param {type:"slider", min:0, max:0.1, step:0.01}
                , zoom_range=[0.7, 1]           
                , horizontal_flip=True          # @param {type:"boolean"} 
                , vertical_flip=True            # @param {type:"boolean"} 
                , fill_mode='constant'          #@param ["constant", "nearest", "reflect", "wrap"] {type:"raw"}
                , data_format='channels_last')

# create the generator
train_gen = DataGenerator(coco, batch_size, img_size, img_ids, img_paths,  cat_to_class, aug_args)
# Out:
# loading annotations into memory...
# Done (t=1.79s)
# creating index...
# index created!

# %% [markdown]
# Show class distribution and class weights from the training set. Class weights are computed according to the following formula:
#
# $w(y) = \frac{n\_samples}{n\_classes \cdot counts(y)}$

# %%
# print class weights
print("CLASS WEIGHTS:")
for i, weight in enumerate(class_weights):
    print("\t- {}: {:.2f}".format(cat_names[i],weight))
    
# plot a pie chart of the class distribution
segmentation_utils.plot_class_dist(class_dist, cat_names, cat_to_class, without_background=True)
# Out:
# CLASS WEIGHTS:
# 	- background: 0.06
# 	- water: 0.35
# 	- egg: 1.02
# 	- butter: 0.63
# 	- bread-white: 0.50
# 	- jam: 1.27
# 	- apple: 1.26
# 	- cheese: 1.58
# 	- carrot: 0.71
# 	- salad-leaf-salad-green: 0.54
# 	- banana: 1.54
# 	- mixed-vegetables: 1.02
# 	- tomato: 0.60
# 	- wine-red: 1.17
# 	- rice: 0.97
# 	- coffee-with-caffeine: 0.73
# 	- potatoes-steamed: 1.41

# %% [markdown]
# Instantiate Data Generators for validation set

# %%
# @title DataGenerator from validation set
path_dir = SRC_PATH+"../data/val/"   # @param {type: "string"}

# load images and other info from annotations (filtering only images containing foods in cat_names)
coco = segmentation_utils.load_coco_dataset(path_dir)
img_ids, img_names, cat_names, cat_to_class = segmentation_utils.load_imgs(coco, cat_names)

img_paths = [os.path.join(path_dir+"images/", file_name) for file_name in img_names]

# create the generator
val_gen = DataGenerator(coco, batch_size, img_size, img_ids, img_paths, cat_to_class)
# Out:
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!

# %% [markdown]
# ### Model architecture
# Basic U-Net

# %%
from tensorflow.keras import layers

def conv_block(input, num_filters, size=3, padding='same', initializer="he_normal"):
    x = layers.Conv2D(filters=num_filters, kernel_size=(size, size), padding=padding, kernel_initializer=initializer)(input)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2D(filters=num_filters, kernel_size=(size, size), padding=padding, kernel_initializer=initializer)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    return x


def deconv_block(input, num_filters, skip_features, size=2, padding='same', strides=(2, 2)):
    x = layers.Conv2DTranspose(num_filters, kernel_size=(size, size), strides=strides, padding=padding)(input)
    x = layers.concatenate([x, skip_features], axis=3)
    x = conv_block(x, num_filters)
    return x

def unet(img_size, num_classes, num_filters=64):
    
    ''' Input layer '''
    input_layer = layers.Input(shape=img_size + (3,), name='image_input')
    
    ''' Contractive path '''
    ### Layer 1
    conv1 = conv_block(input_layer, num_filters=num_filters)
    conv1_out = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    ### Layer 2
    conv2 = conv_block(conv1_out, num_filters=num_filters*2)
    conv2_out = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    ### Layer 3
    conv3 = conv_block(conv2_out, num_filters=num_filters*4)
    conv3_out = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    
    ### Layer 4
    conv4 = conv_block(conv3_out, num_filters=num_filters*8)
    conv4_out = layers.MaxPooling2D(pool_size=(2, 2))(conv4)
    conv4_out = layers.Dropout(0.5)(conv4_out)
    
    ### Layer 5
    conv5 = conv_block(conv4_out, num_filters=num_filters*16)
    conv5 = layers.Dropout(0.5)(conv5)
    
    ''' Expansive path '''
    ### Layer 6
    deconv6 = deconv_block(conv5, num_filters=num_filters*8, skip_features=conv4)
    deconv6 = layers.Dropout(0.5)(deconv6)
    
    ### Layer 7
    deconv7 = deconv_block(deconv6, num_filters=num_filters*4, skip_features=conv3,)
    
    ### Layer 8
    deconv8 = deconv_block(deconv7, num_filters=num_filters*2, skip_features=conv2)
    
    ### Layer 9
    deconv9 = deconv_block(deconv8, num_filters=num_filters, skip_features=conv1)
    
    # output: add a per-pixel classification layer
    output_layer = layers.Conv2D(filters=num_classes, kernel_size=(1, 1), activation="sigmoid", padding="same")(deconv9)
    
    # Define the model
    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='u-net')
    return model

# Free up RAM in case the model definition cells were run multiple times
tf.keras.backend.clear_session()

# Build model
model = unet(img_size, num_classes, num_filters=num_filters)
model.summary()
# Out:
# Model: "u-net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image_input (InputLayer)        [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 896         image_input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8, 8, 256)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 512)    2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 512)    0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 256)  524544      dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 512)  0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 256)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  131200      dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   32832       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 32) 8224        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 32) 9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 32) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 17) 561         activation_17[0][0]
# ==================================================================================================
# Total params: 7,772,401
# Trainable params: 7,766,513
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# Draw model architecture

# %%
import visualkeras
from PIL import ImageFont
from collections import defaultdict

color_map = defaultdict(dict)
color_map[layers.Conv2D]['fill'] = 'red'
color_map[layers.InputLayer]['fill'] = 'gray'
color_map[layers.Dropout]['fill'] = 'blue'
color_map[layers.MaxPooling2D]['fill'] = 'yellow'
color_map[layers.Concatenate]['fill'] = 'green'
color_map[layers.Activation]['fill'] = 'purple'
color_map[layers.Conv2DTranspose]['fill'] = 'orange'


font = ImageFont.truetype("arial.ttf", 32)  
visualkeras.layered_view(model, legend=True, font=font, color_map=color_map)
# Out:
# <PIL.Image.Image image mode=RGBA size=2656x755 at 0x1E1E138BF40>

# %% [markdown]
# ### Training phase
# Configure the model for the training

# %%
# Combo loss 
loss = sm.losses.BinaryFocalLoss() + sm.losses.DiceLoss(class_weights=class_weights)

threshold = 0.5
metrics = [  sm.metrics.IOUScore(threshold=threshold)
           , sm.metrics.Precision(threshold=threshold)
           , sm.metrics.Recall(threshold=threshold)
           , sm.metrics.FScore(threshold=threshold)]

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001)
              , loss=loss
              , metrics=metrics)

# %%
cp_file_name = "weights_model_A_80e.h5"

callbacks = [
    # Model checkpoint save weights ad other informations
    tf.keras.callbacks.ModelCheckpoint(  cp_file_name 
                                       , monitor = 'loss'    # Select which quantity to refers, can also use metrics or the validation 
                                       , verbose = 1
                                       , save_best_only = True 
                                       , mode = 'auto' 
                                       , save_freq = 'epoch' # Flag to save at each epoch 
                                       )
    , tf.keras.callbacks.TensorBoard(log_dir="tensorboard_model_A")
]

# Train the model, doing validation at the end of each epoch.
epochs = 80
history = model.fit(train_gen, epochs=epochs, validation_data=val_gen, callbacks=callbacks)
# Out:
# Epoch 1/80
# 169/169 [==============================] - 1017s 6s/step - loss: 1.0452 - mean_io_u: 0.4704 - iou_score: 0.0488 - precision: 0.1301 - recall: 0.2214 - f1-score: 0.0740 - val_loss: 1.0155 - val_mean_io_u: 0.4703 - val_iou_score: 0.0411 - val_precision: 0.1004 - val_recall: 0.2417 - val_f1-score: 0.0731
#
# Epoch 00001: loss improved from inf to 1.00940, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 2/80
# 169/169 [==============================] - 982s 6s/step - loss: 0.9619 - mean_io_u: 0.4703 - iou_score: 0.1092 - precision: 0.2835 - recall: 0.2211 - f1-score: 0.1617 - val_loss: 1.1484 - val_mean_io_u: 0.4820 - val_iou_score: 0.0354 - val_precision: 0.1709 - val_recall: 0.1332 - val_f1-score: 0.0622
#
# Epoch 00002: loss improved from 1.00940 to 0.94994, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 3/80
# 169/169 [==============================] - 999s 6s/step - loss: 0.9063 - mean_io_u: 0.4703 - iou_score: 0.1487 - precision: 0.2467 - recall: 0.2930 - f1-score: 0.2266 - val_loss: 1.4268 - val_mean_io_u: 0.4760 - val_iou_score: 0.0245 - val_precision: 0.1748 - val_recall: 0.1181 - val_f1-score: 0.0437
#
# Epoch 00003: loss improved from 0.94994 to 0.89737, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 4/80
# 169/169 [==============================] - 968s 6s/step - loss: 0.8747 - mean_io_u: 0.4703 - iou_score: 0.1653 - precision: 0.2581 - recall: 0.3193 - f1-score: 0.2536 - val_loss: 0.9704 - val_mean_io_u: 0.4703 - val_iou_score: 0.0824 - val_precision: 0.1491 - val_recall: 0.2598 - val_f1-score: 0.1357
#
# Epoch 00004: loss improved from 0.89737 to 0.86762, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 5/80
# 169/169 [==============================] - 970s 6s/step - loss: 0.8569 - mean_io_u: 0.4703 - iou_score: 0.1750 - precision: 0.2781 - recall: 0.3254 - f1-score: 0.2677 - val_loss: 0.8605 - val_mean_io_u: 0.4703 - val_iou_score: 0.1606 - val_precision: 0.2760 - val_recall: 0.3138 - val_f1-score: 0.2485
#
# Epoch 00005: loss improved from 0.86762 to 0.85448, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 6/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.8438 - mean_io_u: 0.4703 - iou_score: 0.1845 - precision: 0.2948 - recall: 0.3444 - f1-score: 0.2816 - val_loss: 0.8718 - val_mean_io_u: 0.4703 - val_iou_score: 0.1615 - val_precision: 0.2549 - val_recall: 0.3167 - val_f1-score: 0.2434
#
# Epoch 00006: loss improved from 0.85448 to 0.84257, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 7/80
# 169/169 [==============================] - 987s 6s/step - loss: 0.8380 - mean_io_u: 0.4703 - iou_score: 0.1903 - precision: 0.3054 - recall: 0.3432 - f1-score: 0.2895 - val_loss: 0.8572 - val_mean_io_u: 0.4703 - val_iou_score: 0.1691 - val_precision: 0.2590 - val_recall: 0.3660 - val_f1-score: 0.2573
#
# Epoch 00007: loss improved from 0.84257 to 0.83339, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 8/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.8322 - mean_io_u: 0.4703 - iou_score: 0.1929 - precision: 0.3047 - recall: 0.3549 - f1-score: 0.2924 - val_loss: 0.8178 - val_mean_io_u: 0.4703 - val_iou_score: 0.2006 - val_precision: 0.2878 - val_recall: 0.4068 - val_f1-score: 0.3049
#
# Epoch 00008: loss improved from 0.83339 to 0.82754, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 9/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.8208 - mean_io_u: 0.4703 - iou_score: 0.2033 - precision: 0.3180 - recall: 0.3692 - f1-score: 0.3061 - val_loss: 0.8389 - val_mean_io_u: 0.4703 - val_iou_score: 0.1749 - val_precision: 0.2945 - val_recall: 0.3208 - val_f1-score: 0.2680
#
# Epoch 00009: loss improved from 0.82754 to 0.82266, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 10/80
# 169/169 [==============================] - 985s 6s/step - loss: 0.8089 - mean_io_u: 0.4703 - iou_score: 0.2123 - precision: 0.3297 - recall: 0.3816 - f1-score: 0.3188 - val_loss: 0.8409 - val_mean_io_u: 0.4703 - val_iou_score: 0.1827 - val_precision: 0.3027 - val_recall: 0.3540 - val_f1-score: 0.2756
#
# Epoch 00010: loss improved from 0.82266 to 0.81040, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 11/80
# 169/169 [==============================] - 1065s 6s/step - loss: 0.8054 - mean_io_u: 0.4703 - iou_score: 0.2165 - precision: 0.3355 - recall: 0.3906 - f1-score: 0.3238 - val_loss: 0.8538 - val_mean_io_u: 0.4703 - val_iou_score: 0.1674 - val_precision: 0.2811 - val_recall: 0.3736 - val_f1-score: 0.2588
#
# Epoch 00011: loss improved from 0.81040 to 0.80452, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 12/80
# 169/169 [==============================] - 1046s 6s/step - loss: 0.8023 - mean_io_u: 0.4703 - iou_score: 0.2171 - precision: 0.3387 - recall: 0.3994 - f1-score: 0.3236 - val_loss: 0.8439 - val_mean_io_u: 0.4703 - val_iou_score: 0.1822 - val_precision: 0.3341 - val_recall: 0.3529 - val_f1-score: 0.2741
#
# Epoch 00012: loss improved from 0.80452 to 0.79963, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 13/80
# 169/169 [==============================] - 998s 6s/step - loss: 0.7902 - mean_io_u: 0.4703 - iou_score: 0.2240 - precision: 0.3475 - recall: 0.3910 - f1-score: 0.3340 - val_loss: 0.8321 - val_mean_io_u: 0.4703 - val_iou_score: 0.1777 - val_precision: 0.3296 - val_recall: 0.3163 - val_f1-score: 0.2686
#
# Epoch 00013: loss improved from 0.79963 to 0.79125, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 14/80
# 169/169 [==============================] - 986s 6s/step - loss: 0.7904 - mean_io_u: 0.4703 - iou_score: 0.2244 - precision: 0.3505 - recall: 0.3894 - f1-score: 0.3345 - val_loss: 0.8407 - val_mean_io_u: 0.4703 - val_iou_score: 0.1870 - val_precision: 0.3211 - val_recall: 0.2933 - val_f1-score: 0.2749
#
# Epoch 00014: loss improved from 0.79125 to 0.78768, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 15/80
# 169/169 [==============================] - 972s 6s/step - loss: 0.7839 - mean_io_u: 0.4703 - iou_score: 0.2313 - precision: 0.3594 - recall: 0.3976 - f1-score: 0.3428 - val_loss: 0.8158 - val_mean_io_u: 0.4703 - val_iou_score: 0.1994 - val_precision: 0.3228 - val_recall: 0.3556 - val_f1-score: 0.2980
#
# Epoch 00015: loss improved from 0.78768 to 0.78145, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 16/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.7724 - mean_io_u: 0.4703 - iou_score: 0.2373 - precision: 0.3694 - recall: 0.3990 - f1-score: 0.3505 - val_loss: 0.7928 - val_mean_io_u: 0.4703 - val_iou_score: 0.2183 - val_precision: 0.3547 - val_recall: 0.3707 - val_f1-score: 0.3218
#
# Epoch 00016: loss improved from 0.78145 to 0.77599, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 17/80
# 169/169 [==============================] - 979s 6s/step - loss: 0.7642 - mean_io_u: 0.4703 - iou_score: 0.2442 - precision: 0.3817 - recall: 0.4154 - f1-score: 0.3606 - val_loss: 0.7939 - val_mean_io_u: 0.4703 - val_iou_score: 0.2189 - val_precision: 0.3613 - val_recall: 0.3562 - val_f1-score: 0.3220
# Epoch 00017: loss improved from 0.77599 to 0.76491, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 18/80
# 169/169 [==============================] - 966s 6s/step - loss: 0.7724 - mean_io_u: 0.4703 - iou_score: 0.2404 - precision: 0.3766 - recall: 0.4073 - f1-score: 0.3525 - val_loss: 0.8197 - val_mean_io_u: 0.4703 - val_iou_score: 0.1924 - val_precision: 0.3685 - val_recall: 0.3211 - val_f1-score: 0.2844
#
# Epoch 00018: loss did not improve from 0.76491
# Epoch 19/80
# 169/169 [==============================] - 978s 6s/step - loss: 0.7532 - mean_io_u: 0.4703 - iou_score: 0.2543 - precision: 0.3920 - recall: 0.4252 - f1-score: 0.3711 - val_loss: 0.7951 - val_mean_io_u: 0.4703 - val_iou_score: 0.2160 - val_precision: 0.3809 - val_recall: 0.3612 - val_f1-score: 0.3160
#
# Epoch 00019: loss improved from 0.76491 to 0.75258, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 20/80
# 169/169 [==============================] - 1011s 6s/step - loss: 0.7537 - mean_io_u: 0.4703 - iou_score: 0.2558 - precision: 0.3918 - recall: 0.4261 - f1-score: 0.3721 - val_loss: 0.7666 - val_mean_io_u: 0.4703 - val_iou_score: 0.2368 - val_precision: 0.3701 - val_recall: 0.3786 - val_f1-score: 0.3464
#
# Epoch 00020: loss improved from 0.75258 to 0.74857, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 21/80
# 169/169 [==============================] - 990s 6s/step - loss: 0.7437 - mean_io_u: 0.4703 - iou_score: 0.2648 - precision: 0.4056 - recall: 0.4375 - f1-score: 0.3829 - val_loss: 0.7902 - val_mean_io_u: 0.4703 - val_iou_score: 0.2239 - val_precision: 0.3375 - val_recall: 0.4096 - val_f1-score: 0.3293
#
# Epoch 00021: loss improved from 0.74857 to 0.74533, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 22/80
# 169/169 [==============================] - 1063s 6s/step - loss: 0.7485 - mean_io_u: 0.4703 - iou_score: 0.2608 - precision: 0.4001 - recall: 0.4268 - f1-score: 0.3772 - val_loss: 0.8167 - val_mean_io_u: 0.4703 - val_iou_score: 0.2061 - val_precision: 0.3617 - val_recall: 0.3499 - val_f1-score: 0.3035
#
# Epoch 00022: loss improved from 0.74533 to 0.74168, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 23/80
# 169/169 [==============================] - 1052s 6s/step - loss: 0.7324 - mean_io_u: 0.4704 - iou_score: 0.2730 - precision: 0.4193 - recall: 0.4430 - f1-score: 0.3926 - val_loss: 0.8304 - val_mean_io_u: 0.4703 - val_iou_score: 0.1920 - val_precision: 0.3831 - val_recall: 0.3431 - val_f1-score: 0.2842
#
# Epoch 00023: loss improved from 0.74168 to 0.73276, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 24/80
# 169/169 [==============================] - 1032s 6s/step - loss: 0.7382 - mean_io_u: 0.4703 - iou_score: 0.2719 - precision: 0.4140 - recall: 0.4387 - f1-score: 0.3905 - val_loss: 0.7826 - val_mean_io_u: 0.4703 - val_iou_score: 0.2300 - val_precision: 0.3936 - val_recall: 0.3946 - val_f1-score: 0.3297
#
# Epoch 00024: loss improved from 0.73276 to 0.73252, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 25/80
# 169/169 [==============================] - 994s 6s/step - loss: 0.7169 - mean_io_u: 0.4703 - iou_score: 0.2894 - precision: 0.4352 - recall: 0.4628 - f1-score: 0.4108 - val_loss: 0.7464 - val_mean_io_u: 0.4703 - val_iou_score: 0.2542 - val_precision: 0.4559 - val_recall: 0.3757 - val_f1-score: 0.3604
#
# Epoch 00025: loss improved from 0.73252 to 0.72001, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 26/80
# 169/169 [==============================] - 1002s 6s/step - loss: 0.7100 - mean_io_u: 0.4703 - iou_score: 0.2928 - precision: 0.4442 - recall: 0.4583 - f1-score: 0.4151 - val_loss: 0.7737 - val_mean_io_u: 0.4703 - val_iou_score: 0.2360 - val_precision: 0.4907 - val_recall: 0.3358 - val_f1-score: 0.3310
#
# Epoch 00026: loss improved from 0.72001 to 0.71491, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 27/80
# 169/169 [==============================] - 1065s 6s/step - loss: 0.7165 - mean_io_u: 0.4703 - iou_score: 0.2896 - precision: 0.4400 - recall: 0.4584 - f1-score: 0.4096 - val_loss: 0.7507 - val_mean_io_u: 0.4704 - val_iou_score: 0.2555 - val_precision: 0.4575 - val_recall: 0.3699 - val_f1-score: 0.3596
#
# Epoch 00027: loss improved from 0.71491 to 0.71108, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 28/80
# 169/169 [==============================] - 1099s 7s/step - loss: 0.7087 - mean_io_u: 0.4703 - iou_score: 0.2947 - precision: 0.4496 - recall: 0.4605 - f1-score: 0.4162 - val_loss: 0.7499 - val_mean_io_u: 0.4703 - val_iou_score: 0.2522 - val_precision: 0.4743 - val_recall: 0.3491 - val_f1-score: 0.3551
#
# Epoch 00028: loss improved from 0.71108 to 0.70424, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 29/80
# 169/169 [==============================] - 1044s 6s/step - loss: 0.6980 - mean_io_u: 0.4703 - iou_score: 0.3052 - precision: 0.4618 - recall: 0.4771 - f1-score: 0.4283 - val_loss: 0.7519 - val_mean_io_u: 0.4703 - val_iou_score: 0.2557 - val_precision: 0.4807 - val_recall: 0.3648 - val_f1-score: 0.3582
#
# Epoch 00029: loss improved from 0.70424 to 0.69505, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 30/80
# 169/169 [==============================] - 1002s 6s/step - loss: 0.7067 - mean_io_u: 0.4703 - iou_score: 0.2989 - precision: 0.4550 - recall: 0.4647 - f1-score: 0.4192 - val_loss: 0.7224 - val_mean_io_u: 0.4703 - val_iou_score: 0.2908 - val_precision: 0.4690 - val_recall: 0.4199 - val_f1-score: 0.4001
#
# Epoch 00030: loss did not improve from 0.69505
# Epoch 31/80
# 169/169 [==============================] - 992s 6s/step - loss: 0.6855 - mean_io_u: 0.4703 - iou_score: 0.3146 - precision: 0.4782 - recall: 0.4730 - f1-score: 0.4376 - val_loss: 0.7966 - val_mean_io_u: 0.4703 - val_iou_score: 0.2292 - val_precision: 0.5314 - val_recall: 0.3240 - val_f1-score: 0.3150
#
# Epoch 00031: loss improved from 0.69505 to 0.68241, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 32/80
# 169/169 [==============================] - 1044s 6s/step - loss: 0.6813 - mean_io_u: 0.4704 - iou_score: 0.3165 - precision: 0.4778 - recall: 0.4757 - f1-score: 0.4404 - val_loss: 0.7179 - val_mean_io_u: 0.4703 - val_iou_score: 0.2855 - val_precision: 0.4805 - val_recall: 0.4028 - val_f1-score: 0.3927
#
# Epoch 00032: loss improved from 0.68241 to 0.68133, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 33/80
# 169/169 [==============================] - 1011s 6s/step - loss: 0.6722 - mean_io_u: 0.4703 - iou_score: 0.3282 - precision: 0.4904 - recall: 0.4967 - f1-score: 0.4527 - val_loss: 0.7476 - val_mean_io_u: 0.4714 - val_iou_score: 0.2624 - val_precision: 0.4690 - val_recall: 0.4065 - val_f1-score: 0.3603
#
# Epoch 00033: loss improved from 0.68133 to 0.67316, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 34/80
# 169/169 [==============================] - 984s 6s/step - loss: 0.6729 - mean_io_u: 0.4703 - iou_score: 0.3259 - precision: 0.4904 - recall: 0.4863 - f1-score: 0.4494 - val_loss: 0.7183 - val_mean_io_u: 0.4703 - val_iou_score: 0.2883 - val_precision: 0.5040 - val_recall: 0.3887 - val_f1-score: 0.3972
# Epoch 00034: loss improved from 0.67316 to 0.66763, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 35/80
# 169/169 [==============================] - 1009s 6s/step - loss: 0.6592 - mean_io_u: 0.4703 - iou_score: 0.3373 - precision: 0.5038 - recall: 0.4995 - f1-score: 0.4634 - val_loss: 0.7083 - val_mean_io_u: 0.4703 - val_iou_score: 0.2958 - val_precision: 0.4794 - val_recall: 0.4305 - val_f1-score: 0.4125
#
# Epoch 00035: loss improved from 0.66763 to 0.65935, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 36/80
# 169/169 [==============================] - 968s 6s/step - loss: 0.6672 - mean_io_u: 0.4704 - iou_score: 0.3346 - precision: 0.4998 - recall: 0.4970 - f1-score: 0.4575 - val_loss: 0.7102 - val_mean_io_u: 0.4703 - val_iou_score: 0.2944 - val_precision: 0.5158 - val_recall: 0.4067 - val_f1-score: 0.4009
#
# Epoch 00036: loss did not improve from 0.65935
# Epoch 37/80
# 169/169 [==============================] - 991s 6s/step - loss: 0.6580 - mean_io_u: 0.4703 - iou_score: 0.3406 - precision: 0.5056 - recall: 0.5021 - f1-score: 0.4656 - val_loss: 0.7019 - val_mean_io_u: 0.4703 - val_iou_score: 0.2926 - val_precision: 0.4846 - val_recall: 0.4293 - val_f1-score: 0.4047
#
# Epoch 00037: loss improved from 0.65935 to 0.65387, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 38/80
# 169/169 [==============================] - 970s 6s/step - loss: 0.6578 - mean_io_u: 0.4703 - iou_score: 0.3381 - precision: 0.5027 - recall: 0.4987 - f1-score: 0.4635 - val_loss: 0.6816 - val_mean_io_u: 0.4703 - val_iou_score: 0.3141 - val_precision: 0.5125 - val_recall: 0.4382 - val_f1-score: 0.4281
#
# Epoch 00038: loss improved from 0.65387 to 0.64895, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 39/80
# 169/169 [==============================] - 966s 6s/step - loss: 0.6389 - mean_io_u: 0.4703 - iou_score: 0.3572 - precision: 0.5254 - recall: 0.5185 - f1-score: 0.4832 - val_loss: 0.6942 - val_mean_io_u: 0.4703 - val_iou_score: 0.3021 - val_precision: 0.5254 - val_recall: 0.4285 - val_f1-score: 0.4153
#
# Epoch 00039: loss improved from 0.64895 to 0.64492, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 40/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.6368 - mean_io_u: 0.4704 - iou_score: 0.3558 - precision: 0.5220 - recall: 0.5142 - f1-score: 0.4820 - val_loss: 0.7206 - val_mean_io_u: 0.4703 - val_iou_score: 0.2869 - val_precision: 0.5297 - val_recall: 0.3712 - val_f1-score: 0.3918
#
# Epoch 00040: loss improved from 0.64492 to 0.64152, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 41/80
# 169/169 [==============================] - 969s 6s/step - loss: 0.6313 - mean_io_u: 0.4703 - iou_score: 0.3630 - precision: 0.5339 - recall: 0.5291 - f1-score: 0.4909 - val_loss: 0.6777 - val_mean_io_u: 0.4703 - val_iou_score: 0.3112 - val_precision: 0.5098 - val_recall: 0.4455 - val_f1-score: 0.4286
#
# Epoch 00041: loss improved from 0.64152 to 0.63118, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 42/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.6292 - mean_io_u: 0.4703 - iou_score: 0.3655 - precision: 0.5339 - recall: 0.5312 - f1-score: 0.4930 - val_loss: 0.6788 - val_mean_io_u: 0.4704 - val_iou_score: 0.3195 - val_precision: 0.5461 - val_recall: 0.4560 - val_f1-score: 0.4309
#
# Epoch 00042: loss did not improve from 0.63118
# Epoch 43/80
# 169/169 [==============================] - 967s 6s/step - loss: 0.6244 - mean_io_u: 0.4703 - iou_score: 0.3711 - precision: 0.5381 - recall: 0.5302 - f1-score: 0.4978 - val_loss: 0.6758 - val_mean_io_u: 0.4705 - val_iou_score: 0.3283 - val_precision: 0.5706 - val_recall: 0.4463 - val_f1-score: 0.4348
#
# Epoch 00043: loss improved from 0.63118 to 0.62815, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 44/80
# 169/169 [==============================] - 966s 6s/step - loss: 0.6269 - mean_io_u: 0.4703 - iou_score: 0.3701 - precision: 0.5386 - recall: 0.5318 - f1-score: 0.4968 - val_loss: 0.6625 - val_mean_io_u: 0.4703 - val_iou_score: 0.3327 - val_precision: 0.5506 - val_recall: 0.4262 - val_f1-score: 0.4459
#
# Epoch 00044: loss improved from 0.62815 to 0.62428, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 45/80
# 169/169 [==============================] - 966s 6s/step - loss: 0.6270 - mean_io_u: 0.4703 - iou_score: 0.3702 - precision: 0.5341 - recall: 0.5319 - f1-score: 0.4959 - val_loss: 0.6834 - val_mean_io_u: 0.4703 - val_iou_score: 0.3156 - val_precision: 0.5012 - val_recall: 0.4439 - val_f1-score: 0.4311
#
# Epoch 00045: loss improved from 0.62428 to 0.62360, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 46/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.6219 - mean_io_u: 0.4703 - iou_score: 0.3727 - precision: 0.5407 - recall: 0.5320 - f1-score: 0.4997 - val_loss: 0.6993 - val_mean_io_u: 0.4705 - val_iou_score: 0.3017 - val_precision: 0.5050 - val_recall: 0.4405 - val_f1-score: 0.4137
#
# Epoch 00046: loss improved from 0.62360 to 0.62259, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 47/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.6194 - mean_io_u: 0.4703 - iou_score: 0.3753 - precision: 0.5405 - recall: 0.5429 - f1-score: 0.5025 - val_loss: 0.7053 - val_mean_io_u: 0.4704 - val_iou_score: 0.2979 - val_precision: 0.5559 - val_recall: 0.4188 - val_f1-score: 0.4057
#
# Epoch 00047: loss improved from 0.62259 to 0.61592, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 48/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.6290 - mean_io_u: 0.4704 - iou_score: 0.3675 - precision: 0.5367 - recall: 0.5285 - f1-score: 0.4935 - val_loss: 0.6941 - val_mean_io_u: 0.4703 - val_iou_score: 0.3000 - val_precision: 0.5454 - val_recall: 0.4240 - val_f1-score: 0.4039
#
# Epoch 00048: loss did not improve from 0.61592
# Epoch 49/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.6126 - mean_io_u: 0.4703 - iou_score: 0.3820 - precision: 0.5470 - recall: 0.5487 - f1-score: 0.5092 - val_loss: 0.6724 - val_mean_io_u: 0.4709 - val_iou_score: 0.3224 - val_precision: 0.5349 - val_recall: 0.4676 - val_f1-score: 0.4358
#
# Epoch 00049: loss improved from 0.61592 to 0.60887, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 50/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.6111 - mean_io_u: 0.4703 - iou_score: 0.3832 - precision: 0.5488 - recall: 0.5448 - f1-score: 0.5105 - val_loss: 0.6702 - val_mean_io_u: 0.4703 - val_iou_score: 0.3151 - val_precision: 0.5824 - val_recall: 0.4108 - val_f1-score: 0.4235
#
# Epoch 00050: loss improved from 0.60887 to 0.60669, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 51/80
# 169/169 [==============================] - 969s 6s/step - loss: 0.6071 - mean_io_u: 0.4703 - iou_score: 0.3880 - precision: 0.5544 - recall: 0.5501 - f1-score: 0.5143 - val_loss: 0.6812 - val_mean_io_u: 0.4704 - val_iou_score: 0.3152 - val_precision: 0.5815 - val_recall: 0.4339 - val_f1-score: 0.4252
#
# Epoch 00051: loss improved from 0.60669 to 0.60615, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 52/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.6091 - mean_io_u: 0.4703 - iou_score: 0.3875 - precision: 0.5542 - recall: 0.5452 - f1-score: 0.5147 - val_loss: 0.6580 - val_mean_io_u: 0.4703 - val_iou_score: 0.3450 - val_precision: 0.5397 - val_recall: 0.4703 - val_f1-score: 0.4575
#
# Epoch 00052: loss improved from 0.60615 to 0.60267, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 53/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.6003 - mean_io_u: 0.4704 - iou_score: 0.3974 - precision: 0.5663 - recall: 0.5600 - f1-score: 0.5246 - val_loss: 0.6824 - val_mean_io_u: 0.4704 - val_iou_score: 0.3338 - val_precision: 0.5975 - val_recall: 0.4459 - val_f1-score: 0.4396
#
# Epoch 00053: loss improved from 0.60267 to 0.59668, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 54/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.5953 - mean_io_u: 0.4704 - iou_score: 0.4004 - precision: 0.5692 - recall: 0.5646 - f1-score: 0.5264 - val_loss: 0.6464 - val_mean_io_u: 0.4704 - val_iou_score: 0.3532 - val_precision: 0.5820 - val_recall: 0.4760 - val_f1-score: 0.4634
#
# Epoch 00054: loss did not improve from 0.59668
# Epoch 55/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.6033 - mean_io_u: 0.4704 - iou_score: 0.3958 - precision: 0.5590 - recall: 0.5553 - f1-score: 0.5209 - val_loss: 0.6622 - val_mean_io_u: 0.4715 - val_iou_score: 0.3409 - val_precision: 0.5665 - val_recall: 0.4637 - val_f1-score: 0.4489
#
# Epoch 00055: loss did not improve from 0.59668
# Epoch 56/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.6021 - mean_io_u: 0.4703 - iou_score: 0.3940 - precision: 0.5609 - recall: 0.5530 - f1-score: 0.5207 - val_loss: 0.6622 - val_mean_io_u: 0.4703 - val_iou_score: 0.3382 - val_precision: 0.5624 - val_recall: 0.4581 - val_f1-score: 0.4513
#
# Epoch 00056: loss improved from 0.59668 to 0.58899, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 57/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.5911 - mean_io_u: 0.4703 - iou_score: 0.4039 - precision: 0.5725 - recall: 0.5664 - f1-score: 0.5317 - val_loss: 0.6569 - val_mean_io_u: 0.4706 - val_iou_score: 0.3429 - val_precision: 0.5156 - val_recall: 0.4794 - val_f1-score: 0.4558
#
# Epoch 00057: loss did not improve from 0.58899
# Epoch 58/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.5886 - mean_io_u: 0.4704 - iou_score: 0.4061 - precision: 0.5701 - recall: 0.5667 - f1-score: 0.5331 - val_loss: 0.6574 - val_mean_io_u: 0.4703 - val_iou_score: 0.3458 - val_precision: 0.5796 - val_recall: 0.4528 - val_f1-score: 0.4570
#
# Epoch 00058: loss improved from 0.58899 to 0.58751, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 59/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.5834 - mean_io_u: 0.4703 - iou_score: 0.4115 - precision: 0.5772 - recall: 0.5754 - f1-score: 0.5389 - val_loss: 0.6198 - val_mean_io_u: 0.4703 - val_iou_score: 0.3841 - val_precision: 0.5776 - val_recall: 0.5102 - val_f1-score: 0.5029
#
# Epoch 00059: loss improved from 0.58751 to 0.58506, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 60/80
# 169/169 [==============================] - 964s 6s/step - loss: 0.5885 - mean_io_u: 0.4703 - iou_score: 0.4080 - precision: 0.5736 - recall: 0.5743 - f1-score: 0.5341 - val_loss: 0.6394 - val_mean_io_u: 0.4703 - val_iou_score: 0.3608 - val_precision: 0.5993 - val_recall: 0.4659 - val_f1-score: 0.4724
#
# Epoch 00060: loss did not improve from 0.58506
# Epoch 61/80
# 169/169 [==============================] - 969s 6s/step - loss: 0.5783 - mean_io_u: 0.4703 - iou_score: 0.4163 - precision: 0.5816 - recall: 0.5741 - f1-score: 0.5424 - val_loss: 0.6164 - val_mean_io_u: 0.4705 - val_iou_score: 0.3749 - val_precision: 0.5761 - val_recall: 0.5132 - val_f1-score: 0.4911
#
# Epoch 00061: loss improved from 0.58506 to 0.57989, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 62/80
# 169/169 [==============================] - 966s 6s/step - loss: 0.5783 - mean_io_u: 0.4703 - iou_score: 0.4187 - precision: 0.5839 - recall: 0.5828 - f1-score: 0.5455 - val_loss: 0.6565 - val_mean_io_u: 0.4703 - val_iou_score: 0.3444 - val_precision: 0.5803 - val_recall: 0.4357 - val_f1-score: 0.4523
#
# Epoch 00062: loss improved from 0.57989 to 0.57535, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 63/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.5904 - mean_io_u: 0.4703 - iou_score: 0.4088 - precision: 0.5816 - recall: 0.5679 - f1-score: 0.5352 - val_loss: 0.6318 - val_mean_io_u: 0.4703 - val_iou_score: 0.3666 - val_precision: 0.5785 - val_recall: 0.4839 - val_f1-score: 0.4833
#
# Epoch 00063: loss did not improve from 0.57535
# Epoch 64/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.5876 - mean_io_u: 0.4704 - iou_score: 0.4110 - precision: 0.5778 - recall: 0.5671 - f1-score: 0.5379 - val_loss: 0.6483 - val_mean_io_u: 0.4703 - val_iou_score: 0.3463 - val_precision: 0.6130 - val_recall: 0.4513 - val_f1-score: 0.4554
#
# Epoch 00064: loss did not improve from 0.57535
# Epoch 65/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.5734 - mean_io_u: 0.4703 - iou_score: 0.4221 - precision: 0.5932 - recall: 0.5831 - f1-score: 0.5500 - val_loss: 0.6257 - val_mean_io_u: 0.4703 - val_iou_score: 0.3715 - val_precision: 0.5754 - val_recall: 0.4714 - val_f1-score: 0.4911
#
# Epoch 00065: loss improved from 0.57535 to 0.57166, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 66/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.5793 - mean_io_u: 0.4704 - iou_score: 0.4161 - precision: 0.5792 - recall: 0.5785 - f1-score: 0.5421 - val_loss: 0.6478 - val_mean_io_u: 0.4704 - val_iou_score: 0.3621 - val_precision: 0.5539 - val_recall: 0.5085 - val_f1-score: 0.4838
#
# Epoch 00066: loss did not improve from 0.57166
# Epoch 67/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.5671 - mean_io_u: 0.4703 - iou_score: 0.4278 - precision: 0.5927 - recall: 0.5864 - f1-score: 0.5535 - val_loss: 0.6356 - val_mean_io_u: 0.4710 - val_iou_score: 0.3715 - val_precision: 0.5844 - val_recall: 0.5030 - val_f1-score: 0.4826
#
# Epoch 00067: loss improved from 0.57166 to 0.56697, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 68/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.5560 - mean_io_u: 0.4704 - iou_score: 0.4381 - precision: 0.6047 - recall: 0.5961 - f1-score: 0.5648 - val_loss: 0.6141 - val_mean_io_u: 0.4703 - val_iou_score: 0.3798 - val_precision: 0.6177 - val_recall: 0.4817 - val_f1-score: 0.4925
#
# Epoch 00068: loss improved from 0.56697 to 0.56318, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 69/80
# 169/169 [==============================] - 962s 6s/step - loss: 0.5706 - mean_io_u: 0.4703 - iou_score: 0.4258 - precision: 0.5888 - recall: 0.5850 - f1-score: 0.5515 - val_loss: 0.6302 - val_mean_io_u: 0.4703 - val_iou_score: 0.3617 - val_precision: 0.6022 - val_recall: 0.4637 - val_f1-score: 0.4730
#
# Epoch 00069: loss did not improve from 0.56318
# Epoch 70/80
# 169/169 [==============================] - 960s 6s/step - loss: 0.5641 - mean_io_u: 0.4703 - iou_score: 0.4299 - precision: 0.6000 - recall: 0.5818 - f1-score: 0.5569 - val_loss: 0.6862 - val_mean_io_u: 0.4703 - val_iou_score: 0.3234 - val_precision: 0.5596 - val_recall: 0.4372 - val_f1-score: 0.4337
# Epoch 00070: loss did not improve from 0.56318
# Epoch 71/80
# 169/169 [==============================] - 963s 6s/step - loss: 0.5586 - mean_io_u: 0.4703 - iou_score: 0.4364 - precision: 0.6061 - recall: 0.5975 - f1-score: 0.5646 - val_loss: 0.5858 - val_mean_io_u: 0.4704 - val_iou_score: 0.4110 - val_precision: 0.5970 - val_recall: 0.5244 - val_f1-score: 0.5324
#
# Epoch 00071: loss improved from 0.56318 to 0.55819, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 72/80
# 169/169 [==============================] - 961s 6s/step - loss: 0.5630 - mean_io_u: 0.4703 - iou_score: 0.4400 - precision: 0.6050 - recall: 0.6001 - f1-score: 0.5644 - val_loss: 0.6318 - val_mean_io_u: 0.4703 - val_iou_score: 0.3647 - val_precision: 0.6161 - val_recall: 0.4962 - val_f1-score: 0.4793
#
# Epoch 00072: loss did not improve from 0.55819
# Epoch 73/80
# 169/169 [==============================] - 969s 6s/step - loss: 0.5560 - mean_io_u: 0.4704 - iou_score: 0.4379 - precision: 0.6034 - recall: 0.5910 - f1-score: 0.5639 - val_loss: 0.6009 - val_mean_io_u: 0.4704 - val_iou_score: 0.3936 - val_precision: 0.6104 - val_recall: 0.5105 - val_f1-score: 0.5066
#
# Epoch 00073: loss did not improve from 0.55819
# Epoch 74/80
# 169/169 [==============================] - 965s 6s/step - loss: 0.5602 - mean_io_u: 0.4703 - iou_score: 0.4405 - precision: 0.6039 - recall: 0.5988 - f1-score: 0.5663 - val_loss: 0.6416 - val_mean_io_u: 0.4703 - val_iou_score: 0.3712 - val_precision: 0.6244 - val_recall: 0.4570 - val_f1-score: 0.4762
#
# Epoch 00074: loss improved from 0.55819 to 0.55548, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 75/80
# 169/169 [==============================] - 1076s 6s/step - loss: 0.5587 - mean_io_u: 0.4704 - iou_score: 0.4423 - precision: 0.6031 - recall: 0.6029 - f1-score: 0.5668 - val_loss: 0.6565 - val_mean_io_u: 0.4703 - val_iou_score: 0.3432 - val_precision: 0.5699 - val_recall: 0.4759 - val_f1-score: 0.4586
#
# Epoch 00075: loss did not improve from 0.55548
# Epoch 76/80
# 169/169 [==============================] - 1084s 6s/step - loss: 0.5502 - mean_io_u: 0.4704 - iou_score: 0.4478 - precision: 0.6064 - recall: 0.6026 - f1-score: 0.5728 - val_loss: 0.6363 - val_mean_io_u: 0.4703 - val_iou_score: 0.3727 - val_precision: 0.6136 - val_recall: 0.4626 - val_f1-score: 0.4786
#
# Epoch 00076: loss improved from 0.55548 to 0.55378, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 77/80
# 169/169 [==============================] - 1047s 6s/step - loss: 0.5445 - mean_io_u: 0.4704 - iou_score: 0.4500 - precision: 0.6170 - recall: 0.6044 - f1-score: 0.5765 - val_loss: 0.6108 - val_mean_io_u: 0.4705 - val_iou_score: 0.3958 - val_precision: 0.6325 - val_recall: 0.4942 - val_f1-score: 0.5119
#
# Epoch 00077: loss improved from 0.55378 to 0.54698, saving model to model\food_segmentation_50_epochs_sigmoid_binary_focal_dice_loss_128_class_weights_adam_32_filters_20210606-114504.h5
# Epoch 78/80
# 169/169 [==============================] - 1038s 6s/step - loss: 0.5513 - mean_io_u: 0.4704 - iou_score: 0.4445 - precision: 0.6090 - recall: 0.6020 - f1-score: 0.5697 - val_loss: 0.6568 - val_mean_io_u: 0.4703 - val_iou_score: 0.3437 - val_precision: 0.5958 - val_recall: 0.4964 - val_f1-score: 0.4518
#
# Epoch 00078: loss did not improve from 0.54698
# Epoch 79/80
# 169/169 [==============================] - 978s 6s/step - loss: 0.5422 - mean_io_u: 0.4704 - iou_score: 0.4528 - precision: 0.6146 - recall: 0.6081 - f1-score: 0.5782 - val_loss: 0.5874 - val_mean_io_u: 0.4705 - val_iou_score: 0.4078 - val_precision: 0.6107 - val_recall: 0.5324 - val_f1-score: 0.5254
#
# Epoch 00079: loss did not improve from 0.54698
# Epoch 80/80
# 169/169 [==============================] - 1034s 6s/step - loss: 0.5616 - mean_io_u: 0.4704 - iou_score: 0.4373 - precision: 0.6022 - recall: 0.6026 - f1-score: 0.5628 - val_loss: 0.5993 - val_mean_io_u: 0.4703 - val_iou_score: 0.3859 - val_precision: 0.6184 - val_recall: 0.4713 - val_f1-score: 0.4996
#
# Epoch 00080: loss did not improve from 0.54698

# %% [markdown]
# ### History of the training
# Plot metrics evolution from 0 to 80 epoch during the training

# %%
import matplotlib.pyplot as plt
def plot_history(model_history, keys, labels=("epochs", "metrics"), figsize=(10,5)):
    
    fig = plt.figure(figsize=figsize)
    
    # take all pairs of training and val metrics
    for i in range(0, len(keys), 2):
        m, val_m = keys[i], keys[i+1]
        
        plt.plot(model_history.history[m])
        plt.plot(model_history.history[val_m])
        
    plt.xlabel(labels[0])
    plt.ylabel(labels[1])

    # Adding legend
    plt.legend(keys,
          title ="Legend",
          loc ="upper left",
          bbox_to_anchor =(1.0, 0, 0.5, 1))
    plt.title("Training history")
    plt.grid(True)
    plt.show()

# %%
# plot history
plot_history(history,['loss','val_loss'], labels=("epochs", "loss"), figsize=(15,7))
plot_history(history,['iou_score','val_iou_score', 'precision', 'val_precision', 'recall', 'val_recall'], figsize=(15,7))

# %% [markdown]
# Store model and history on files

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_A.json", "w") as json_file:
    json_file.write(model_json)

# %%
import pandas as pd

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open("train_history_model_A.csv", mode="w") as file:
    hist_df.to_csv(file)
